# %% [markdown]
# A simplified implementation of the CNNpred paper has been done. Here 2d CNNpred version has been used on DJI, NASDAQ, NYSE, RUSSELL and S&P data.
#
# Reference:
# https://machinelearningmastery.com/using-cnn-for-financial-time-series-prediction/

# %%
import random

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Input
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, mean_absolute_error

# %%
#sample dataset
df = pd.read_csv('https://raw.githubusercontent.com/mandalnilabja/soc2022/main/data/Processed_DJI.csv', index_col="Date", parse_dates=True)
df.head()
# Out:
#                    Close    Volume       mom      mom1      mom2      mom3  \
# Date
# 2009-12-31  10428.049805       NaN       NaN       NaN       NaN       NaN
# 2010-01-04  10583.959961       NaN  0.014951       NaN       NaN       NaN
# 2010-01-05  10572.019531       NaN -0.001128  0.014951       NaN       NaN
# 2010-01-06  10573.679688  0.515598  0.000157 -0.001128  0.014951       NaN
# 2010-01-07  10606.860352  9.776045  0.003138  0.000157 -0.001128  0.014951
#
#             ROC_5  ROC_10  ROC_15  ROC_20  ...   NZD  silver-F  RUSSELL-F  \
# Date                                       ...
# 2009-12-31    NaN     NaN     NaN     NaN  ...  0.03      0.26      -1.08
# 2010-01-04    NaN     NaN     NaN     NaN  ...  1.52      3.26       1.61
# 2010-01-05    NaN     NaN     NaN     NaN  ... -0.07      1.96      -0.20
# 2010-01-06    NaN     NaN     NaN     NaN  ...  0.56      2.15      -0.02
# 2010-01-07    NaN     NaN     NaN     NaN  ... -0.72      0.94       0.50
#
#             S&P-F   CHF  Dollar index-F  Dollar index  wheat-F   XAG   XAU
# Date
# 2009-12-31  -1.00 -0.11           -0.08         -0.06    -0.48  0.30  0.39
# 2010-01-04   1.62 -0.57           -0.59         -0.42     3.12  3.91  2.10
# 2010-01-05   0.31  0.43            0.03          0.12    -0.90  1.42 -0.12
# 2010-01-06   0.07 -0.56           -0.24         -0.17     2.62  2.25  1.77
# 2010-01-07   0.40  0.58            0.58          0.54    -1.85  0.22 -0.58
#
# [5 rows x 83 columns]

# %%
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall
 
def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
 
def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))
 
def f1macro(y_true, y_pred):
    f_pos = f1_m(y_true, y_pred)
    # negative version of the data and prediction
    f_neg = f1_m(1-y_true, 1-K.clip(y_pred,0,1))
    return (f_pos + f_neg)/2

# %%
def cnnpred_2d(seq_len=60, n_features=82, n_filters=(8,8,8), droprate=0.1):
    #2D-CNNpred model according to the paper
    model = Sequential([
        Input(shape=(seq_len, n_features, 1)),
        Conv2D(n_filters[0], kernel_size=(1, n_features), activation="relu"),
        Conv2D(n_filters[1], kernel_size=(3,1), activation="relu"),
        MaxPool2D(pool_size=(2,1)),
        Conv2D(n_filters[2], kernel_size=(3,1), activation="relu"),
        MaxPool2D(pool_size=(2,1)),
        Flatten(),
        Dropout(droprate),
        Dense(1, activation="sigmoid")
    ])
    return model

# %%
def datagen(data, seq_len, batch_size, targetcol, kind):
    #As a generator to produce samples for Keras model
    batch = []
    while True:
        # Pick one dataframe from the pool
        key = random.choice(list(data.keys()))
        df = data[key]
        input_cols = [c for c in df.columns if c != targetcol]
        index = df.index[df.index < TRAIN_TEST_CUTOFF]
        split = int(len(index) * TRAIN_VALID_RATIO)
        if kind == 'train':
            index = index[:split]   # range for the training set
        elif kind == 'valid':
            index = index[split:]   # range for the validation set
        # Pick one position, then clip a sequence length
        while True:
            t = random.choice(index)      # pick one time step
            n = (df.index == t).argmax()  # find its position in the dataframe
            if n-seq_len+1 < 0:
                continue # can't get enough data for one sequence length
            frame = df.iloc[n-seq_len+1:n+1]
            batch.append([frame[input_cols].values, df.loc[t, targetcol]])
            break
        # if we get enough for a batch, dispatch
        if len(batch) == batch_size:
            X, y = zip(*batch)
            X, y = np.expand_dims(np.array(X), 3), np.array(y)
            yield X, y
            batch = []

# %%
def testgen(data, seq_len, targetcol):
    #Return array of all test samples
    batch = []
    for key, df in data.items():
        input_cols = [c for c in df.columns if c != targetcol]
        # find the start of test sample
        t = df.index[df.index >= TRAIN_TEST_CUTOFF][0]
        n = (df.index == t).argmax()
        # extract sample using a sliding window
        for i in range(n+1, len(df)+1):
            frame = df.iloc[i-seq_len:i]
            batch.append([frame[input_cols].values, frame[targetcol][-1]])
    X, y = zip(*batch)
    return np.expand_dims(np.array(X),3), np.array(y)

# %%
dir={'DJI':'https://raw.githubusercontent.com/mandalnilabja/soc2022/main/data/Processed_DJI.csv',
     'NASDAQ':'https://raw.githubusercontent.com/mandalnilabja/soc2022/main/data/Processed_NASDAQ.csv',
     'NYSE':'https://raw.githubusercontent.com/mandalnilabja/soc2022/main/data/Processed_NYSE.csv',
     'RUSSELL':'https://raw.githubusercontent.com/mandalnilabja/soc2022/main/data/Processed_RUSSELL.csv',
     'S&P':'https://raw.githubusercontent.com/mandalnilabja/soc2022/main/data/Processed_S&P.csv'
     }


TRAIN_TEST_CUTOFF = '2016-04-21'
TRAIN_VALID_RATIO = 0.75


data = {}


for name, filepath in dir.items():
    X = pd.read_csv(filepath, index_col="Date", parse_dates=True)
    
    # basic preprocessing: get the name, the classification
    del X["Name"]
    cols = X.columns
    
    # Save the target variable as a column in dataframe and drop NaN values
    X["Target"] = (X["Close"].pct_change().shift(-1) > 0).astype(int)
    X.dropna(inplace=True)
   
    # Fit the standard scaler using the training dataset not whole data set
    index = X.index[X.index > TRAIN_TEST_CUTOFF]
    index = index[:int(len(index) * TRAIN_VALID_RATIO)]
    scaler = StandardScaler().fit(X.loc[index, cols])
    
    # Save scale transformed dataframe
    X[cols] = scaler.transform(X[cols])
    data[name] = X

# %%
print(data)

# %%
#CNNpred paper parameters
seq_len = 60 # for 60 past days data
n_features = 82 # no of features engineered and used

#hyperparameters that can be varied
n_epochs = 20


accuracy=[]
MAE=[]
F1=[]


for batch_size in [128, 64, 32, 16]:
  
  # Produce CNNpred as a binary classification problem
  model = cnnpred_2d(seq_len, n_features)
  model.compile(optimizer="adam", loss="mae", metrics=["acc", f1macro])
  model.summary()  # print model structure to console
  
  # Set up callbacks and fit the model
  # We use custom validation score f1macro() and hence monitor for "val_f1macro"
  checkpoint_path = "./cp2d-{epoch}-{val_f1macro:.2f}.h5"
  callbacks = [
      ModelCheckpoint(checkpoint_path,
                      monitor='val_f1macro', mode="max",
                      verbose=0, save_best_only=True, save_weights_only=False, save_freq="epoch")
  ]
  #fitting the model
  model.fit(datagen(data, seq_len, batch_size, "Target", "train"),
            validation_data=datagen(data, seq_len, batch_size, "Target", "valid"),
            epochs=n_epochs, steps_per_epoch=400, validation_steps=10, verbose=1, callbacks=callbacks)
  

  # Prepare test data
  test_data, test_target = testgen(data, seq_len, "Target")
  
  # Test the model
  test_out = model.predict(test_data)
  test_pred = (test_out > 0.5).astype(int)
  
  accuracy.append(accuracy_score(test_pred, test_target))
  MAE.append(mean_absolute_error(test_pred, test_target))
  F1.append(f1_score(test_pred, test_target))
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_27 (Conv2D)          (None, 60, 1, 8)          664
#
#  conv2d_28 (Conv2D)          (None, 58, 1, 8)          200
#
#  max_pooling2d_18 (MaxPoolin  (None, 29, 1, 8)         0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 27, 1, 8)          200
#
#  max_pooling2d_19 (MaxPoolin  (None, 13, 1, 8)         0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 104)               0
#
#  dropout_9 (Dropout)         (None, 104)               0
#
#  dense_9 (Dense)             (None, 1)                 105
#
# =================================================================
# Total params: 1,169
# Trainable params: 1,169
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 400/400 [==============================] - 51s 126ms/step - loss: 0.4426 - acc: 0.5586 - f1macro: 0.3622 - val_loss: 0.4977 - val_acc: 0.5039 - val_f1macro: 0.3345
# Epoch 2/20
# 400/400 [==============================] - 51s 127ms/step - loss: 0.3847 - acc: 0.6262 - f1macro: 0.5315 - val_loss: 0.4867 - val_acc: 0.5109 - val_f1macro: 0.4448
# Epoch 3/20
# 400/400 [==============================] - 50s 125ms/step - loss: 0.2768 - acc: 0.7400 - f1macro: 0.7198 - val_loss: 0.4808 - val_acc: 0.5273 - val_f1macro: 0.4986
# Epoch 4/20
# 400/400 [==============================] - 51s 127ms/step - loss: 0.2337 - acc: 0.7802 - f1macro: 0.7664 - val_loss: 0.4857 - val_acc: 0.5148 - val_f1macro: 0.4669
# Epoch 5/20
# 400/400 [==============================] - 49s 124ms/step - loss: 0.2149 - acc: 0.7964 - f1macro: 0.7837 - val_loss: 0.4700 - val_acc: 0.5188 - val_f1macro: 0.4811
# Epoch 6/20
# 400/400 [==============================] - 50s 124ms/step - loss: 0.2034 - acc: 0.8062 - f1macro: 0.7955 - val_loss: 0.4939 - val_acc: 0.5070 - val_f1macro: 0.4729
# Epoch 7/20
# 400/400 [==============================] - 51s 127ms/step - loss: 0.1927 - acc: 0.8147 - f1macro: 0.8032 - val_loss: 0.4981 - val_acc: 0.5063 - val_f1macro: 0.4666
# Epoch 8/20
# 400/400 [==============================] - 51s 127ms/step - loss: 0.1910 - acc: 0.8152 - f1macro: 0.8045 - val_loss: 0.5064 - val_acc: 0.4852 - val_f1macro: 0.4631
# Epoch 9/20
# 400/400 [==============================] - 51s 127ms/step - loss: 0.1856 - acc: 0.8201 - f1macro: 0.8093 - val_loss: 0.4862 - val_acc: 0.5156 - val_f1macro: 0.4814
# Epoch 10/20
# 400/400 [==============================] - 51s 127ms/step - loss: 0.1814 - acc: 0.8239 - f1macro: 0.8146 - val_loss: 0.4622 - val_acc: 0.5437 - val_f1macro: 0.5183
# Epoch 11/20
# 400/400 [==============================] - 51s 128ms/step - loss: 0.1750 - acc: 0.8297 - f1macro: 0.8204 - val_loss: 0.4999 - val_acc: 0.4969 - val_f1macro: 0.4497
# Epoch 12/20
# 400/400 [==============================] - 50s 124ms/step - loss: 0.1706 - acc: 0.8342 - f1macro: 0.8261 - val_loss: 0.4868 - val_acc: 0.5180 - val_f1macro: 0.4886
# Epoch 13/20
# 400/400 [==============================] - 51s 127ms/step - loss: 0.1687 - acc: 0.8352 - f1macro: 0.8270 - val_loss: 0.4994 - val_acc: 0.4977 - val_f1macro: 0.4683
# Epoch 14/20
# 400/400 [==============================] - 49s 124ms/step - loss: 0.1647 - acc: 0.8394 - f1macro: 0.8317 - val_loss: 0.4724 - val_acc: 0.5250 - val_f1macro: 0.5044
# Epoch 15/20
# 400/400 [==============================] - 50s 126ms/step - loss: 0.1656 - acc: 0.8379 - f1macro: 0.8304 - val_loss: 0.4753 - val_acc: 0.5250 - val_f1macro: 0.5000
# Epoch 16/20
# 400/400 [==============================] - 50s 124ms/step - loss: 0.1635 - acc: 0.8397 - f1macro: 0.8316 - val_loss: 0.4825 - val_acc: 0.5172 - val_f1macro: 0.4838
# Epoch 17/20
# 400/400 [==============================] - 50s 124ms/step - loss: 0.1622 - acc: 0.8411 - f1macro: 0.8341 - val_loss: 0.4787 - val_acc: 0.5242 - val_f1macro: 0.4914
# Epoch 18/20
# 400/400 [==============================] - 51s 127ms/step - loss: 0.1628 - acc: 0.8401 - f1macro: 0.8326 - val_loss: 0.4613 - val_acc: 0.5398 - val_f1macro: 0.5164
# Epoch 19/20
# 400/400 [==============================] - 50s 125ms/step - loss: 0.1620 - acc: 0.8413 - f1macro: 0.8341 - val_loss: 0.4860 - val_acc: 0.5070 - val_f1macro: 0.4765
# Epoch 20/20
# 400/400 [==============================] - 50s 124ms/step - loss: 0.1558 - acc: 0.8473 - f1macro: 0.8403 - val_loss: 0.4721 - val_acc: 0.5320 - val_f1macro: 0.5055
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_30 (Conv2D)          (None, 60, 1, 8)          664
#
#  conv2d_31 (Conv2D)          (None, 58, 1, 8)          200
#
#  max_pooling2d_20 (MaxPoolin  (None, 29, 1, 8)         0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 27, 1, 8)          200
#
#  max_pooling2d_21 (MaxPoolin  (None, 13, 1, 8)         0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 104)               0
#
#  dropout_10 (Dropout)        (None, 104)               0
#
#  dense_10 (Dense)            (None, 1)                 105
#
# =================================================================
# Total params: 1,169
# Trainable params: 1,169
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 400/400 [==============================] - 28s 69ms/step - loss: 0.4428 - acc: 0.5596 - f1macro: 0.3583 - val_loss: 0.4628 - val_acc: 0.5375 - val_f1macro: 0.3486
# Epoch 2/20
# 400/400 [==============================] - 27s 68ms/step - loss: 0.4412 - acc: 0.5588 - f1macro: 0.3575 - val_loss: 0.4984 - val_acc: 0.5016 - val_f1macro: 0.3335
# Epoch 3/20
# 400/400 [==============================] - 27s 68ms/step - loss: 0.4393 - acc: 0.5607 - f1macro: 0.3583 - val_loss: 0.4953 - val_acc: 0.5047 - val_f1macro: 0.3346
# Epoch 4/20
# 400/400 [==============================] - 27s 67ms/step - loss: 0.4353 - acc: 0.5647 - f1macro: 0.3601 - val_loss: 0.4781 - val_acc: 0.5219 - val_f1macro: 0.3420
# Epoch 5/20
# 400/400 [==============================] - 27s 68ms/step - loss: 0.4400 - acc: 0.5600 - f1macro: 0.3580 - val_loss: 0.4730 - val_acc: 0.5266 - val_f1macro: 0.3438
# Epoch 6/20
# 400/400 [==============================] - 27s 68ms/step - loss: 0.4101 - acc: 0.5942 - f1macro: 0.4609 - val_loss: 0.5134 - val_acc: 0.4719 - val_f1macro: 0.3971
# Epoch 7/20
# 400/400 [==============================] - 27s 69ms/step - loss: 0.3500 - acc: 0.6604 - f1macro: 0.6018 - val_loss: 0.4909 - val_acc: 0.5109 - val_f1macro: 0.4608
# Epoch 8/20
# 400/400 [==============================] - 27s 67ms/step - loss: 0.3090 - acc: 0.7021 - f1macro: 0.6634 - val_loss: 0.4874 - val_acc: 0.5172 - val_f1macro: 0.4696
# Epoch 9/20
# 400/400 [==============================] - 27s 67ms/step - loss: 0.2891 - acc: 0.7210 - f1macro: 0.6897 - val_loss: 0.4625 - val_acc: 0.5406 - val_f1macro: 0.5115
# Epoch 10/20
# 400/400 [==============================] - 27s 67ms/step - loss: 0.2721 - acc: 0.7368 - f1macro: 0.7062 - val_loss: 0.4516 - val_acc: 0.5609 - val_f1macro: 0.5036
# Epoch 11/20
# 400/400 [==============================] - 27s 67ms/step - loss: 0.2583 - acc: 0.7490 - f1macro: 0.7214 - val_loss: 0.4726 - val_acc: 0.5312 - val_f1macro: 0.4841
# Epoch 12/20
# 400/400 [==============================] - 27s 67ms/step - loss: 0.2554 - acc: 0.7510 - f1macro: 0.7226 - val_loss: 0.4695 - val_acc: 0.5312 - val_f1macro: 0.4751
# Epoch 13/20
# 400/400 [==============================] - 28s 69ms/step - loss: 0.2485 - acc: 0.7582 - f1macro: 0.7329 - val_loss: 0.4820 - val_acc: 0.5172 - val_f1macro: 0.4695
# Epoch 14/20
# 400/400 [==============================] - 27s 69ms/step - loss: 0.2434 - acc: 0.7623 - f1macro: 0.7377 - val_loss: 0.4649 - val_acc: 0.5406 - val_f1macro: 0.4813
# Epoch 15/20
# 400/400 [==============================] - 27s 69ms/step - loss: 0.2407 - acc: 0.7637 - f1macro: 0.7417 - val_loss: 0.4372 - val_acc: 0.5703 - val_f1macro: 0.5129
# Epoch 16/20
# 400/400 [==============================] - 27s 69ms/step - loss: 0.2357 - acc: 0.7693 - f1macro: 0.7462 - val_loss: 0.4972 - val_acc: 0.5047 - val_f1macro: 0.4682
# Epoch 17/20
# 400/400 [==============================] - 27s 67ms/step - loss: 0.2325 - acc: 0.7717 - f1macro: 0.7500 - val_loss: 0.4811 - val_acc: 0.5234 - val_f1macro: 0.4847
# Epoch 18/20
# 400/400 [==============================] - 27s 67ms/step - loss: 0.2241 - acc: 0.7806 - f1macro: 0.7591 - val_loss: 0.5125 - val_acc: 0.4797 - val_f1macro: 0.4396
# Epoch 19/20
# 400/400 [==============================] - 27s 67ms/step - loss: 0.2203 - acc: 0.7839 - f1macro: 0.7635 - val_loss: 0.4624 - val_acc: 0.5391 - val_f1macro: 0.4718
# Epoch 20/20
# 400/400 [==============================] - 27s 67ms/step - loss: 0.2129 - acc: 0.7916 - f1macro: 0.7741 - val_loss: 0.5031 - val_acc: 0.4969 - val_f1macro: 0.4387
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_33 (Conv2D)          (None, 60, 1, 8)          664
#
#  conv2d_34 (Conv2D)          (None, 58, 1, 8)          200
#
#  max_pooling2d_22 (MaxPoolin  (None, 29, 1, 8)         0
#  g2D)
#
#  conv2d_35 (Conv2D)          (None, 27, 1, 8)          200
#
#  max_pooling2d_23 (MaxPoolin  (None, 13, 1, 8)         0
#  g2D)
#
#  flatten_11 (Flatten)        (None, 104)               0
#
#  dropout_11 (Dropout)        (None, 104)               0
#
#  dense_11 (Dense)            (None, 1)                 105
#
# =================================================================
# Total params: 1,169
# Trainable params: 1,169
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.4468 - acc: 0.5556 - f1macro: 0.3659 - val_loss: 0.4814 - val_acc: 0.5188 - val_f1macro: 0.3388
# Epoch 2/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.4383 - acc: 0.5627 - f1macro: 0.3725 - val_loss: 0.4821 - val_acc: 0.5188 - val_f1macro: 0.3735
# Epoch 3/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.4304 - acc: 0.5707 - f1macro: 0.3974 - val_loss: 0.4921 - val_acc: 0.5094 - val_f1macro: 0.3776
# Epoch 4/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.4164 - acc: 0.5849 - f1macro: 0.4158 - val_loss: 0.5248 - val_acc: 0.4688 - val_f1macro: 0.3514
# Epoch 5/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.3780 - acc: 0.6313 - f1macro: 0.5405 - val_loss: 0.4698 - val_acc: 0.5437 - val_f1macro: 0.4578
# Epoch 6/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.3134 - acc: 0.6996 - f1macro: 0.6526 - val_loss: 0.4830 - val_acc: 0.5250 - val_f1macro: 0.4743
# Epoch 7/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.2836 - acc: 0.7281 - f1macro: 0.6951 - val_loss: 0.5034 - val_acc: 0.5219 - val_f1macro: 0.4947
# Epoch 8/20
# 400/400 [==============================] - 15s 36ms/step - loss: 0.2638 - acc: 0.7482 - f1macro: 0.7178 - val_loss: 0.5052 - val_acc: 0.5063 - val_f1macro: 0.4673
# Epoch 9/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.2449 - acc: 0.7641 - f1macro: 0.7353 - val_loss: 0.4815 - val_acc: 0.5344 - val_f1macro: 0.4992
# Epoch 10/20
# 400/400 [==============================] - 15s 38ms/step - loss: 0.2455 - acc: 0.7631 - f1macro: 0.7400 - val_loss: 0.5237 - val_acc: 0.4625 - val_f1macro: 0.4405
# Epoch 11/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.2392 - acc: 0.7681 - f1macro: 0.7465 - val_loss: 0.4955 - val_acc: 0.4969 - val_f1macro: 0.4644
# Epoch 12/20
# 400/400 [==============================] - 15s 38ms/step - loss: 0.2332 - acc: 0.7739 - f1macro: 0.7502 - val_loss: 0.5083 - val_acc: 0.5031 - val_f1macro: 0.4874
# Epoch 13/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.2297 - acc: 0.7773 - f1macro: 0.7501 - val_loss: 0.4551 - val_acc: 0.5469 - val_f1macro: 0.5298
# Epoch 14/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.2250 - acc: 0.7809 - f1macro: 0.7553 - val_loss: 0.4800 - val_acc: 0.5063 - val_f1macro: 0.4810
# Epoch 15/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.2268 - acc: 0.7793 - f1macro: 0.7587 - val_loss: 0.4791 - val_acc: 0.5250 - val_f1macro: 0.5063
# Epoch 16/20
# 400/400 [==============================] - 15s 38ms/step - loss: 0.2238 - acc: 0.7824 - f1macro: 0.7635 - val_loss: 0.5032 - val_acc: 0.4875 - val_f1macro: 0.4486
# Epoch 17/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.2128 - acc: 0.7927 - f1macro: 0.7727 - val_loss: 0.4908 - val_acc: 0.5188 - val_f1macro: 0.5040
# Epoch 18/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.2084 - acc: 0.7971 - f1macro: 0.7794 - val_loss: 0.4932 - val_acc: 0.5156 - val_f1macro: 0.5092
# Epoch 19/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.2095 - acc: 0.7955 - f1macro: 0.7791 - val_loss: 0.4999 - val_acc: 0.4875 - val_f1macro: 0.4662
# Epoch 20/20
# 400/400 [==============================] - 15s 37ms/step - loss: 0.2061 - acc: 0.7984 - f1macro: 0.7799 - val_loss: 0.4763 - val_acc: 0.5094 - val_f1macro: 0.4863
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 60, 1, 8)          664
#
#  conv2d_37 (Conv2D)          (None, 58, 1, 8)          200
#
#  max_pooling2d_24 (MaxPoolin  (None, 29, 1, 8)         0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 27, 1, 8)          200
#
#  max_pooling2d_25 (MaxPoolin  (None, 13, 1, 8)         0
#  g2D)
#
#  flatten_12 (Flatten)        (None, 104)               0
#
#  dropout_12 (Dropout)        (None, 104)               0
#
#  dense_12 (Dense)            (None, 1)                 105
#
# =================================================================
# Total params: 1,169
# Trainable params: 1,169
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 400/400 [==============================] - 10s 22ms/step - loss: 0.4538 - acc: 0.5492 - f1macro: 0.3569 - val_loss: 0.5489 - val_acc: 0.4500 - val_f1macro: 0.3032
# Epoch 2/20
# 400/400 [==============================] - 9s 22ms/step - loss: 0.4377 - acc: 0.5623 - f1macro: 0.3555 - val_loss: 0.4938 - val_acc: 0.5063 - val_f1macro: 0.3342
# Epoch 3/20
# 400/400 [==============================] - 9s 22ms/step - loss: 0.4445 - acc: 0.5555 - f1macro: 0.3530 - val_loss: 0.5438 - val_acc: 0.4563 - val_f1macro: 0.3054
# Epoch 4/20
# 400/400 [==============================] - 9s 22ms/step - loss: 0.4538 - acc: 0.5462 - f1macro: 0.3490 - val_loss: 0.5064 - val_acc: 0.4938 - val_f1macro: 0.3279
# Epoch 5/20
# 400/400 [==============================] - 9s 21ms/step - loss: 0.4477 - acc: 0.5523 - f1macro: 0.3510 - val_loss: 0.5374 - val_acc: 0.4625 - val_f1macro: 0.3109
# Epoch 6/20
# 400/400 [==============================] - 9s 22ms/step - loss: 0.4472 - acc: 0.5528 - f1macro: 0.3517 - val_loss: 0.5062 - val_acc: 0.4938 - val_f1macro: 0.3220
# Epoch 7/20
# 400/400 [==============================] - 9s 21ms/step - loss: 0.4431 - acc: 0.5569 - f1macro: 0.3538 - val_loss: 0.5562 - val_acc: 0.4437 - val_f1macro: 0.3055
# Epoch 8/20
# 400/400 [==============================] - 9s 21ms/step - loss: 0.4480 - acc: 0.5520 - f1macro: 0.3513 - val_loss: 0.4939 - val_acc: 0.5063 - val_f1macro: 0.3266
# Epoch 9/20
# 400/400 [==============================] - 9s 22ms/step - loss: 0.4309 - acc: 0.5691 - f1macro: 0.3584 - val_loss: 0.4188 - val_acc: 0.5813 - val_f1macro: 0.3641
# Epoch 10/20
# 400/400 [==============================] - 9s 21ms/step - loss: 0.4423 - acc: 0.5577 - f1macro: 0.3533 - val_loss: 0.4751 - val_acc: 0.5250 - val_f1macro: 0.3406
# Epoch 11/20
# 400/400 [==============================] - 9s 22ms/step - loss: 0.4339 - acc: 0.5661 - f1macro: 0.3572 - val_loss: 0.5374 - val_acc: 0.4625 - val_f1macro: 0.3131
# Epoch 12/20
# 400/400 [==============================] - 9s 22ms/step - loss: 0.4402 - acc: 0.5598 - f1macro: 0.3549 - val_loss: 0.4693 - val_acc: 0.5312 - val_f1macro: 0.3436
# Epoch 13/20
# 400/400 [==============================] - 9s 22ms/step - loss: 0.4348 - acc: 0.5663 - f1macro: 0.3813 - val_loss: 0.4928 - val_acc: 0.5125 - val_f1macro: 0.3602
# Epoch 14/20
# 400/400 [==============================] - 9s 22ms/step - loss: 0.4278 - acc: 0.5763 - f1macro: 0.4451 - val_loss: 0.5188 - val_acc: 0.4812 - val_f1macro: 0.4393
# Epoch 15/20
# 400/400 [==============================] - 8s 21ms/step - loss: 0.3773 - acc: 0.6313 - f1macro: 0.5531 - val_loss: 0.5397 - val_acc: 0.4750 - val_f1macro: 0.3948
# Epoch 16/20
# 400/400 [==============================] - 9s 22ms/step - loss: 0.3602 - acc: 0.6491 - f1macro: 0.5737 - val_loss: 0.4530 - val_acc: 0.5688 - val_f1macro: 0.4780
# Epoch 17/20
# 400/400 [==============================] - 9s 21ms/step - loss: 0.3477 - acc: 0.6620 - f1macro: 0.5998 - val_loss: 0.4787 - val_acc: 0.5437 - val_f1macro: 0.4939
# Epoch 18/20
# 400/400 [==============================] - 9s 22ms/step - loss: 0.3259 - acc: 0.6831 - f1macro: 0.6381 - val_loss: 0.4706 - val_acc: 0.5437 - val_f1macro: 0.4834
# Epoch 19/20
# 400/400 [==============================] - 8s 21ms/step - loss: 0.3045 - acc: 0.7058 - f1macro: 0.6656 - val_loss: 0.5084 - val_acc: 0.4750 - val_f1macro: 0.4235
# Epoch 20/20
# 400/400 [==============================] - 9s 21ms/step - loss: 0.2881 - acc: 0.7208 - f1macro: 0.6895 - val_loss: 0.4591 - val_acc: 0.5375 - val_f1macro: 0.4962

# %% [markdown]
# Batch size of 128
#
# 66s for one epoch with only CPU
#
# 64s for one epoch with GPU
#
# Total: 17m for 20 epochs
#
# For the whole execution batch size [128, 64, 32, 16] total 24m was taking

# %% [markdown]
# Reducing batch size significantly improves f1 macro score. Maximum f1 score is achieved for batch size of 32

# %%
print(accuracy)
print(MAE)
print(F1)
# Out:
# [0.48097560975609754, 0.5375609756097561, 0.504390243902439, 0.5482926829268293]
# [0.5190243902439025, 0.4624390243902439, 0.49560975609756097, 0.45170731707317074]
# [0.551433389544688, 0.6589928057553958, 0.6037441497659906, 0.6505660377358491]
