# %% [markdown]
# #NIFTY50 2dCNNpred

# %%
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Input
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, mean_absolute_error

# %%
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall
 
def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
 
def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))
 
def f1macro(y_true, y_pred):
    f_pos = f1_m(y_true, y_pred)
    # negative version of the data and prediction
    f_neg = f1_m(1-y_true, 1-K.clip(y_pred,0,1))
    return (f_pos + f_neg)/2

# %%
def cnnpred_2d(seq_len=60, n_features=12, n_filters=(8,8,8), droprate=0.1):
    #2D-CNNpred model according to the paper
    model = Sequential([
        Input(shape=(seq_len, n_features, 1)),
        Conv2D(n_filters[0], kernel_size=(1, n_features), activation="relu"),
        Conv2D(n_filters[1], kernel_size=(3,1), activation="relu"),
        MaxPool2D(pool_size=(2,1)),
        Conv2D(n_filters[2], kernel_size=(3,1), activation="relu"),
        MaxPool2D(pool_size=(2,1)),
        Flatten(),
        Dropout(droprate),
        Dense(1, activation="sigmoid")
    ])
    return model

# %%
def datagen(data, seq_len, batch_size, targetcol, kind):
    #As a generator to produce samples for Keras model
    batch = []
    while True:
        df = data
        input_cols = [c for c in df.columns if c != targetcol]
        index = df.index[df.index < TRAIN_TEST_CUTOFF]
        split = int(len(index) * TRAIN_VALID_RATIO)
        if kind == 'train':
            index = index[:split]   # range for the training set
        elif kind == 'valid':
            index = index[split:]   # range for the validation set
        
        # Pick one position, then clip a sequence length
        while True:
            t = random.choice(index)      # pick one time step
            n = (df.index == t).argmax()  # find its position in the dataframe
            if n-seq_len+1 < 0:
                continue # can't get enough data for one sequence length
            frame = df.iloc[n-seq_len+1:n+1]
            batch.append([frame[input_cols].values, df.loc[t, targetcol]])
            break
        # if we get enough for a batch, dispatch
        if len(batch) == batch_size:
            X, y = zip(*batch)
            X, y = np.expand_dims(np.array(X), 3), np.array(y)
            yield X, y
            batch = []

# %%
def testgen(data, seq_len, targetcol):
    #Return array of all test samples
    batch = []
    df=data
    input_cols = [c for c in df.columns if c != targetcol]
    # find the start of test sample
    t = df.index[df.index >= TRAIN_TEST_CUTOFF][0]
    n = (df.index == t).argmax()
    # extract sample using a sliding window
    for i in range(n+1, len(df)+1):
        frame = df.iloc[i-seq_len:i]
        batch.append([frame[input_cols].values, frame[targetcol][-1]])
    X, y = zip(*batch)
    return np.expand_dims(np.array(X),3), np.array(y)

# %%
url='https://raw.githubusercontent.com/mandalnilabja/soc2022/main/data/NSEI.csv'

X = pd.read_csv(url, index_col="Date", parse_dates=True)
X=X[X.Volume>0]
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2316 entries, 2013-01-21 to 2022-07-27
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2316 non-null   float64
#  1   High       2316 non-null   float64
#  2   Low        2316 non-null   float64
#  3   Close      2316 non-null   float64
#  4   Adj Close  2316 non-null   float64
#  5   Volume     2316 non-null   float64
# dtypes: float64(6)
# memory usage: 126.7 KB

# %%
TRAIN_TEST_CUTOFF = '2020-2-11'
TRAIN_VALID_RATIO = 0.75
    
# get the names of columns
cols = X.columns
    
# Save the target variable as a column in dataframe and drop NaN values
X["Target"] = (X["Close"].pct_change().shift(-1) > 0).astype(int)
X.dropna(inplace=True)
   
# Fit the standard scaler using the training dataset not whole data set
index = X.index[X.index > TRAIN_TEST_CUTOFF]
index = index[:int(len(index) * TRAIN_VALID_RATIO)]
scaler = StandardScaler().fit(X.loc[index, cols])
    
# Save scale transformed dataframe
X[cols] = scaler.transform(X[cols])
data = X

# %%
data['RoM3']=data.Close.rolling(3).mean() #Rolling Mean Closing Values of 3 days
data['RoM5']=data.Close.rolling(5).mean() #Rolling Mean Closing Values of 5 days
data['RoM15']=data.Close.rolling(15).mean() #Rolling Mean Closing Values of 15 days
data['RoM30']=data.Close.rolling(30).mean() #Rolling Mean Closing Values of 30 days
data['Vol_Diff'] = data["Volume"].pct_change().shift(-1) #Daily Volume Difference
data['Close_Diff'] = data["Close"].pct_change().shift(-7) #Weekly Closing Value Difference

#Dropping NaN rows
data.dropna(inplace=True)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2280 entries, 2013-03-01 to 2022-07-18
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Open        2280 non-null   float64
#  1   High        2280 non-null   float64
#  2   Low         2280 non-null   float64
#  3   Close       2280 non-null   float64
#  4   Adj Close   2280 non-null   float64
#  5   Volume      2280 non-null   float64
#  6   Target      2280 non-null   int64
#  7   RoM3        2280 non-null   float64
#  8   RoM5        2280 non-null   float64
#  9   RoM15       2280 non-null   float64
#  10  RoM30       2280 non-null   float64
#  11  Vol_Diff    2280 non-null   float64
#  12  Close_Diff  2280 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 249.4 KB

# %%
#CNNpred paper parameters
seq_len = 60 # for 60 past days data
n_features = 12 # raw features used


index=0

accuracy=[]
MAE=[]
F1=[]
parameters=[]


param_list = [
 ['sgd', 'mae', 0.05], ['adam', 'mae', 0.1], ['adagrad', 'mae',  0.05], ['adamax', 'binary_focal_crossentropy', 0.1], 
 ['sgd', 'binary_focal_crossentropy', 0.1], ['adam', 'binary_focal_crossentropy', 0.15], ['adagrad', 'mae', 0.1], ['adamax', 'binary_focal_crossentropy', 0.15], 
 ['sgd', 'binary_crossentropy', 0.15], ['adam', 'binary_crossentropy', 0.2], ['adagrad', 'hinge', 0.2], ['adamax', 'binary_crossentropy', 0.15],
 ['sgd', 'hinge', 0.2], ['adam', 'hinge',  0.05], ['adagrad', 'hinge',  0.05], ['adamax', 'binary_crossentropy', 0.2]
 ]






for batch_size in [64, 32]:
  for n_epochs in [20, 30]:
    for optim, lossfxn, dr in param_list:
      # Produce CNNpred as a binary classification problem
      if index<26: #continue from last time
        index=index + 1        
        continue

      model = cnnpred_2d(seq_len, n_features, droprate=dr)
      model.compile(optimizer=optim, loss=lossfxn, metrics=["acc", f1macro])
      model.summary()  # print model structure to console
      
      # Set up callbacks and fit the model
      
      # We use custom validation score f1macro() and hence monitor for "val_f1macro"
      checkpoint_path = "./cp2d-{epoch}-{val_f1macro:.2f}.h5"
      callbacks = [
          ModelCheckpoint(checkpoint_path,
                          monitor='val_f1macro', mode="max",
                          verbose=0, save_best_only=True, save_weights_only=False, save_freq="epoch")
      ]
      #fitting the model
      model.fit(datagen(data, seq_len, batch_size, "Target", "train"),
                validation_data=datagen(data, seq_len, batch_size, "Target", "valid"),
                epochs=n_epochs, steps_per_epoch=400, validation_steps=10, verbose=1, callbacks=callbacks)
      

      # Prepare test data
      test_data, test_target = testgen(data, seq_len, "Target")
      
      # Test the model
      test_out = model.predict(test_data)
      test_pred = (test_out > 0.5).astype(int)
      
      #index of model
      index = index + 1 

      #measuring performance
      accuracy.append(accuracy_score(test_pred, test_target))
      MAE.append(mean_absolute_error(test_pred, test_target))
      F1.append(f1_score(test_pred, test_target))
      #saving parameters of each model
      parameters.append('{}--{}--{}--{}--{}--{}'.format(index,n_epochs,optim,batch_size,dr,lossfxn))
      #saving the model
      model.save('2dCNNpredNIFTY50m{}.h5'.format(index))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 60, 1, 8)          104
#
#  conv2d_1 (Conv2D)           (None, 58, 1, 8)          200
#
#  max_pooling2d (MaxPooling2D  (None, 29, 1, 8)         0
#  )
#
#  conv2d_2 (Conv2D)           (None, 27, 1, 8)          200
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 1, 8)         0
#  2D)
#
#  flatten (Flatten)           (None, 104)               0
#
#  dropout (Dropout)           (None, 104)               0
#
#  dense (Dense)               (None, 1)                 105
#
# =================================================================
# Total params: 609
# Trainable params: 609
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 400/400 [==============================] - 45s 82ms/step - loss: 0.9572 - acc: 0.5281 - f1macro: 0.3445 - val_loss: 0.9024 - val_acc: 0.5625 - val_f1macro: 0.3648
# Epoch 2/30
# 400/400 [==============================] - 25s 63ms/step - loss: 0.9476 - acc: 0.5313 - f1macro: 0.3459 - val_loss: 0.9749 - val_acc: 0.5109 - val_f1macro: 0.3482
# Epoch 3/30
# 400/400 [==============================] - 27s 66ms/step - loss: 0.9548 - acc: 0.5259 - f1macro: 0.3435 - val_loss: 0.9768 - val_acc: 0.5094 - val_f1macro: 0.3444
# Epoch 4/30
# 400/400 [==============================] - 26s 65ms/step - loss: 0.9566 - acc: 0.5241 - f1macro: 0.3428 - val_loss: 0.9455 - val_acc: 0.5297 - val_f1macro: 0.3539
# Epoch 5/30
# 400/400 [==============================] - 25s 63ms/step - loss: 0.9336 - acc: 0.5358 - f1macro: 0.3479 - val_loss: 0.9044 - val_acc: 0.5531 - val_f1macro: 0.3621
# Epoch 6/30
# 400/400 [==============================] - 25s 63ms/step - loss: 0.9450 - acc: 0.5292 - f1macro: 0.3448 - val_loss: 0.9454 - val_acc: 0.5266 - val_f1macro: 0.3492
# Epoch 7/30
# 400/400 [==============================] - 26s 65ms/step - loss: 0.9499 - acc: 0.5263 - f1macro: 0.3437 - val_loss: 0.9886 - val_acc: 0.5047 - val_f1macro: 0.3425
# Epoch 8/30
# 400/400 [==============================] - 25s 63ms/step - loss: 0.9334 - acc: 0.5349 - f1macro: 0.3474 - val_loss: 0.9572 - val_acc: 0.5172 - val_f1macro: 0.3448
# Epoch 9/30
# 400/400 [==============================] - 26s 64ms/step - loss: 0.9521 - acc: 0.5247 - f1macro: 0.3430 - val_loss: 0.9801 - val_acc: 0.5063 - val_f1macro: 0.3421
# Epoch 10/30
# 400/400 [==============================] - 25s 63ms/step - loss: 0.9445 - acc: 0.5286 - f1macro: 0.3449 - val_loss: 0.9897 - val_acc: 0.5000 - val_f1macro: 0.3377
# Epoch 11/30
# 400/400 [==============================] - 26s 64ms/step - loss: 0.9409 - acc: 0.5304 - f1macro: 0.3454 - val_loss: 0.9436 - val_acc: 0.5266 - val_f1macro: 0.3473
# Epoch 12/30
# 400/400 [==============================] - 25s 63ms/step - loss: 0.
30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9382 - acc: 0.5309 - f1macro: 0.3457 - val_loss: 0.9608 - val_acc: 0.5172 - val_f1macro: 0.3398
# Epoch 27/30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9512 - acc: 0.5244 - f1macro: 0.3430 - val_loss: 0.9811 - val_acc: 0.5094 - val_f1macro: 0.3367
# Epoch 28/30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9419 - acc: 0.5291 - f1macro: 0.3447 - val_loss: 0.9218 - val_acc: 0.5391 - val_f1macro: 0.3488
# Epoch 29/30
# 400/400 [==============================] - 26s 64ms/step - loss: 0.9396 - acc: 0.5302 - f1macro: 0.3454 - val_loss: 0.9704 - val_acc: 0.5156 - val_f1macro: 0.3385
# Epoch 30/30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9442 - acc: 0.5279 - f1macro: 0.3444 - val_loss: 0.9754 - val_acc: 0.5125 - val_f1macro: 0.3378
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 60, 1, 8)          104
#
#  conv2d_10 (Conv2D)          (None, 58, 1, 8)          200
#
#  max_pooling2d_6 (MaxPooling  (None, 29, 1, 8)         0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 27, 1, 8)          200
#
#  max_pooling2d_7 (MaxPooling  (None, 13, 1, 8)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 104)               0
#
#  dropout_3 (Dropout)         (None, 104)               0
#
#  dense_3 (Dense)             (None, 1)                 105
#
# =================================================================
# Total params: 609
# Trainable params: 609
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 400/400 [==============================] - 26s 63ms/step - loss: 0.9483 - acc: 0.5284 - f1macro: 0.3494 - val_loss: 0.9163 - val_acc: 0.5437 - val_f1macro: 0.3696
# Epoch 2/30
# 400/400 [==============================] - 26s 64ms/step - loss: 0.9513 - acc: 0.5244 - f1macro: 0.3429 - val_loss: 0.9604 - val_acc: 0.5188 - val_f1macro: 0.3463
# Epoch 3/30
# 400/400 [==============================] - 25s 63ms/step - loss: 0.9427 - acc: 0.5286 - f1macro: 0.3447 - val_loss: 0.9628 - val_acc: 0.5203 - val_f1macro: 0.3463
# Epoch 4/30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9418 - acc: 0.5291 - f1macro: 0.3450 - val_loss: 0.9719 - val_acc: 0.5203 - val_f1macro: 0.3579
# Epoch 5/30
# 400/400 [==============================] - 25s 63ms/step - loss: 0.9455 - acc: 0.5273 - f1macro: 0.3439 - val_loss: 1.0278 - val_acc: 0.4875 - val_f1macro: 0.3323
# Epoch 6/30
# 400/400 [==============================] - 26s 64ms/step - loss: 0.9385 - acc: 0.5307 - f1macro: 0.3457 - val_loss: 0.8887 - val_acc: 0.5562 - val_f1macro: 0.3601
# Epoch 7/30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9419 - acc: 0.5291 - f1macro: 0.3449 - val_loss: 0.8767 - val_acc: 0.5641 - val_f1macro: 0.3685
# Epoch 8/30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9377 - acc: 0.5312 - f1macro: 0.3459 - val_loss: 0.8781 - val_acc: 0.5625 - val_f1macro: 0.3654
# Epoch 9/30
# 400/400 [==============================] - 26s 64ms/step - loss: 0.9383 - acc: 0.5309 - f1macro: 0.3456 - val_loss: 0.9641 - val_acc: 0.5188 - val_f1macro: 0.3428
# Epoch 10/30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9341 - acc: 0.5329 - f1macro: 0.3466 - val_loss: 0.9219 - val_acc: 0.5391 - val_f1macro: 0.3489
# Epoch 11/30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9398 - acc: 0.5301 - f1macro: 0.3453 - val_loss: 0.9734 - val_acc: 0.5141 - val_f1macro: 0.3413
# Epoch 12/30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9341 - acc: 0.5330 - f1macro: 0.3466 - val_loss: 0.9172 - val_acc: 0.5437 - val_f1macro: 0.3611
# Epoch 13/30
# 400/400 [==============================] - 26s 64ms/step - loss: 0.9472 - acc: 0.5264 - f1macro: 0.3438 - val_loss: 0.9422 - val_acc: 0.5297 - val_f1macro: 0.3482
# Epoch 14/30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9428 - acc: 0.5286 - f1macro: 0.3447 - val_loss: 0.8625 - val_acc: 0.5703 - val_f1macro: 0.3687
# Epoch 15/30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9572 - acc: 0.5214 - f1macro: 0.3416 - val_loss: 0.9594 - val_acc: 0.5219 - val_f1macro: 0.3477
# Epoch 16/30
# 400/400 [==============================] - 26s 64ms/step - loss: 0.9513 - acc: 0.5243 - f1macro: 0.3429 - val_loss: 0.9859 - val_acc: 0.5078 - val_f1macro: 0.3389
# Epoch 17/30
# 400/400 [==============================] - 25s 63ms/step - loss: 0.9420 - acc: 0.5290 - f1macro: 0.3448 - val_loss: 0.9640 - val_acc: 0.5203 - val_f1macro: 0.3481
# Epoch 18/30
# 400/400 [==============================] - 25s 63ms/step - loss: 0.9500 - acc: 0.5250 - f1macro: 0.3433 - val_loss: 0.9234 - val_acc: 0.5391 - val_f1macro: 0.3518
# Epoch 19/30
# 400/400 [==============================] - 26s 64ms/step - loss: 0.9420 - acc: 0.5290 - f1macro: 0.3449 - val_loss: 0.9922 - val_acc: 0.5063 - val_f1macro: 0.3418
# Epoch 20/30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9463 - acc: 0.5268 - f1macro: 0.3440 - val_loss: 0.9812 - val_acc: 0.5109 - val_f1macro: 0.3431
# Epoch 21/30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9435 - acc: 0.5282 - f1macro: 0.3445 - val_loss: 0.9234 - val_acc: 0.5406 - val_f1macro: 0.3570
# Epoch 22/30
# 400/400 [==============================] - 25s 63ms/step - loss: 0.9417 - acc: 0.5291 - f1macro: 0.3449 - val_loss: 0.9234 - val_acc: 0.5406 - val_f1macro: 0.3587
# Epoch 23/30
# 400/400 [==============================] - 26s 64ms/step - loss: 0.9482 - acc: 0.5259 - f1macro: 0.3436 - val_loss: 0.9516 - val_acc: 0.5250 - val_f1macro: 0.3466
# Epoch 24/30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9372 - acc: 0.5314 - f1macro: 0.3460 - val_loss: 1.0047 - val_acc: 0.4984 - val_f1macro: 0.3350
# Epoch 25/30
# 400/400 [==============================] - 25s 63ms/step - loss: 0.9338 - acc: 0.5331 - f1macro: 0.3467 - val_loss: 0.9547 - val_acc: 0.5234 - val_f1macro: 0.3449
# Epoch 26/30
# 400/400 [==============================] - 26s 64ms/step - loss: 0.9382 - acc: 0.5309 - f1macro: 0.3455 - val_loss: 0.9641 - val_acc: 0.5188 - val_f1macro: 0.3433
# Epoch 27/30
# 400/400 [==============================] - 25s 63ms/step - loss: 0.9373 - acc: 0.5314 - f1macro: 0.3457 - val_loss: 0.9469 - val_acc: 0.5266 - val_f1macro: 0.3439
# Epoch 28/30
# 400/400 [==============================] - 25s 63ms/step - loss: 0.9387 - acc: 0.5307 - f1macro: 0.3456 - val_loss: 0.9969 - val_acc: 0.5016 - val_f1macro: 0.3324
# Epoch 29/30
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9307 - acc: 0.5346 - f1macro: 0.3473 - val_loss: 1.0125 - val_acc: 0.4938 - val_f1macro: 0.3291
# Epoch 30/30
# 400/400 [==============================] - 26s 64ms/step - loss: 0.9434 - acc: 0.5283 - f1macro: 0.3446 - val_loss: 0.9203 - val_acc: 0.5422 - val_f1macro: 0.3601
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 60, 1, 8)          104
#
#  conv2d_13 (Conv2D)          (None, 58, 1, 8)          200
#
#  max_pooling2d_8 (MaxPooling  (None, 29, 1, 8)         0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 27, 1, 8)          200
#
#  max_pooling2d_9 (MaxPooling  (None, 13, 1, 8)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 104)               0
#
#  dropout_4 (Dropout)         (None, 104)               0
#
#  dense_4 (Dense)             (None, 1)                 105
#
# =================================================================
# Total params: 609
# Trainable params: 609
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
#

# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_108 (Conv2D)         (None, 60, 1, 8)          104
#
#  conv2d_109 (Conv2D)         (None, 58, 1, 8)          200
#
#  max_pooling2d_72 (MaxPoolin  (None, 29, 1, 8)         0
#  g2D)
#
#  conv2d_110 (Conv2D)         (None, 27, 1, 8)          200
#
#  max_pooling2d_73 (MaxPoolin  (None, 13, 1, 8)         0
#  g2D)
#
#  flatten_36 (Flatten)        (None, 104)               0
#
#  dropout_36 (Dropout)        (None, 104)               0
#
#  dense_36 (Dense)            (None, 1)                 105
#
# =================================================================
# Total params: 609
# Trainable params: 609
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 400/400 [==============================] - 17s 41ms/step - loss: 0.9709 - acc: 0.4870 - f1macro: 0.4003 - val_loss: 0.9368 - val_acc: 0.4812 - val_f1macro: 0.4464
# Epoch 2/30
# 400/400 [==============================] - 16s 40ms/step - loss: 0.9731 - acc: 0.5259 - f1macro: 0.4036 - val_loss: 0.9825 - val_acc: 0.5094 - val_f1macro: 0.4164
# Epoch 3/30
# 400/400 [==============================] - 16s 41ms/step - loss: 0.9690 - acc: 0.5264 - f1macro: 0.3443 - val_loss: 0.9603 - val_acc: 0.5188 - val_f1macro: 0.3796
# Epoch 4/30
# 400/400 [==============================] - 17s 42ms/step - loss: 0.9689 - acc: 0.5255 - f1macro: 0.3425 - val_loss: 1.0169 - val_acc: 0.4781 - val_f1macro: 0.3408
# Epoch 5/30
# 400/400 [==============================] - 16s 41ms/step - loss: 0.9475 - acc: 0.5390 - f1macro: 0.3483 - val_loss: 1.0205 - val_acc: 0.4875 - val_f1macro: 0.3451
# Epoch 6/30
# 400/400 [==============================] - 16s 40ms/step - loss: 0.9493 - acc: 0.5347 - f1macro: 0.3463 - val_loss: 1.0800 - val_acc: 0.4437 - val_f1macro: 0.3095
# Epoch 7/30
# 400/400 [==============================] - 16s 41ms/step - loss: 0.9467 - acc: 0.5338 - f1macro: 0.3461 - val_loss: 0.9550 - val_acc: 0.5219 - val_f1macro: 0.3450
# Epoch 8/30
# 400/400 [==============================] - 17s 41ms/step - loss: 0.9483 - acc: 0.5309 - f1macro: 0.3444 - val_loss: 0.9236 - val_acc: 0.5375 - val_f1macro: 0.3526
# Epoch 9/30
# 400/400 [==============================] - 17s 42ms/step - loss: 0.9477 - acc: 0.5304 - f1macro: 0.3444 - val_loss: 0.9990 - val_acc: 0.5000 - val_f1macro: 0.3307
# Epoch 10/30
# 400/400 [==============================] - 16s 41ms/step - loss: 0.9371 - acc: 0.5354 - f1macro: 0.3464 - val_loss: 0.9139 - val_acc: 0.5469 - val_f1macro: 0.3509
# Epoch 11/30
# 400/400 [==============================] - 16s 40ms/step - loss: 0.9521 - acc: 0.5261 - f1macro: 0.3425 - val_loss: 1.0359 - val_acc: 0.4656 - val_f1macro: 0.3165
# Epoch 12/30
# 400/400 [==============================] - 16s 39ms/step - loss: 0.9428 - acc: 0.5309 - f1macro: 0.3446 - val_loss: 0.8944 - val_acc: 0.5594 - val_f1macro: 0.3580
# Epoch 13/30
# 400/400 [==============================] - 16s 39ms/step - loss: 0

# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_111 (Conv2D)         (None, 60, 1, 8)          104
#
#  conv2d_112 (Conv2D)         (None, 58, 1, 8)          200
#
#  max_pooling2d_74 (MaxPoolin  (None, 29, 1, 8)         0
#  g2D)
#
#  conv2d_113 (Conv2D)         (None, 27, 1, 8)          200
#
#  max_pooling2d_75 (MaxPoolin  (None, 13, 1, 8)         0
#  g2D)
#
#  flatten_37 (Flatten)        (None, 104)               0
#
#  dropout_37 (Dropout)        (None, 104)               0
#
#  dense_37 (Dense)            (None, 1)                 105
#
# =================================================================
# Total params: 609
# Trainable params: 609
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 400/400 [==============================] - 16s 40ms/step - loss: 0.6913 - acc: 0.5291 - f1macro: 0.3654 - val_loss: 1.3273 - val_acc: 0.5250 - val_f1macro: 0.4781
# Epoch 2/30
# 400/400 [==============================] - 16s 39ms/step - loss: 0.6912 - acc: 0.5302 - f1macro: 0.3647 - val_loss: 1.1317 - val_acc: 0.5406 - val_f1macro: 0.4660
# Epoch 3/30
# 400/400 [==============================] - 16s 39ms/step - loss: 0.6910 - acc: 0.5297 - f1macro: 0.3551 - val_loss: 1.0056 - val_acc: 0.4781 - val_f1macro: 0.4255
# Epoch 4/30
# 400/400 [==============================] - 17s 42ms/step - loss: 0.6907 - acc: 0.5325 - f1macro: 0.3600 - val_loss: 1.1073 - val_acc: 0.4812 - val_f1macro: 0.4019
# Epoch 5/30
# 400/400 [==============================] - 15s 39ms/step - loss: 0.6900 - acc: 0.5298 - f1macro: 0.3664 - val_loss: 1.4502 - val_acc: 0.4812 - val_f1macro: 0.4175
# Epoch 6/30
# 400/400 [==============================] - 16s 39ms/step - loss: 0.6886 - acc: 0.5337 - f1macro: 0.3758 - val_loss: 1.5853 - val_acc: 0.5375 - val_f1macro: 0.4223
# Epoch 7/30
# 400/400 [==============================] - 16s 40ms/step - loss: 0.6872 - acc: 0.5437 - f1macro: 0.4257 - val_loss: 2.1026 - val_acc: 0.4719 - val_f1macro: 0.4369
# Epoch 8/30
# 400/400 [==============================] - 16s 39ms/step - loss: 0.6852 - acc: 0.5470 - f1macro: 0.4402 - val_loss: 2.6091 - val_acc: 0.5156 - val_f1macro: 0.4430
# Epoch 9/30
# 400/400 [==============================] - 16s 39ms/step - loss: 0.6829 - acc: 0.5476 - f1macro: 0.4552 - val_loss: 2.9604 - val_acc: 0.5688 - val_f1macro: 0.5136
# Epoch 10/30
# 400/400 [==============================] - 17s 42ms/step - loss: 0.6818 - acc: 0.5515 - f1macro: 0.4982 - val_loss: 4.0278 - val_acc: 0.5094 - val_f1macro: 0.4561
# Epoch 11/30
# 400/400 [==============================] - 16s 39ms/step - loss: 0.6810 - acc: 0.5559 - f1macro: 0.4850 - val_loss: 4.2437 - val_acc: 0.5188 - val_f1macro: 0.4577
# Epoch 12/30
# 400/400 [==============================] - 16s 39ms/step - loss: 0.6763 - acc: 0.5621 - f1macro: 0.5060 - val_loss: 7.6886 - val_acc: 0.4844 - val_f1macro: 0.4317
# Epoch 13/30
# 400/400 [==============================] - 16s 39ms/step - loss: 0.6771 - acc: 0.5631 - f1macro: 0.5254 - val_loss: 6.1757 - val_acc: 0.5125 - val_f1macro: 0.4821
# Epoch 14/30
# 400/400 [==============================] - 16s 39ms/step - loss: 0.6751 - acc: 0.5718 - f1macro: 0.5322 - val_loss: 4.2951 - val_acc: 0.4875 - val_f1macro: 0.4635
# Epoch 15/30
# 400/400 [==============================] - 17s 42ms/step - loss: 0.6746 - acc: 0.5698 - f1macro: 0.5368 - val_loss: 11.3041 - val_acc: 0.5375 - val_f1macro: 0.4892
# Epoch 16/30
# 400/400 [==============================] - 16s 39ms/step - loss: 0